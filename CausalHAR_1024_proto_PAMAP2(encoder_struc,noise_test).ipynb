# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler
from collections import Counter
from IPython.display import display
from thop import profile
import glob

pd.set_option('display.max_rows', None)

def set_seed(seed: int = 42):
    import random
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True
set_seed(42)

def load_pamap2_data(dataset_dir="/content/data/PAMAP2_Dataset", window_size=100, step=50):
    file_paths = sorted(glob.glob(os.path.join(dataset_dir, 'Protocol', 'subject*.dat')))
    optional_path = os.path.join(dataset_dir, 'Optional')
    if os.path.exists(optional_path):
        file_paths += sorted(glob.glob(os.path.join(optional_path, 'subject*.dat')))
    if not file_paths:
        return None, None, None
    all_windows = []
    all_labels = []
    for file_path in file_paths:
        subject_id = os.path.basename(file_path).split('.')[0]
        try:
            df = pd.read_csv(file_path, sep='\s+', header=None, na_values='NaN')
            df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
            if df_cleaned.empty:
                continue
            labels = df_cleaned.iloc[:, 1].values.astype(int)
            hand_cols = list(range(4, 20))
            chest_cols = list(range(21, 37))
            ankle_cols = list(range(38, 54))
            all_sensor_cols = hand_cols + chest_cols + ankle_cols
            if df_cleaned.shape[1] < max(all_sensor_cols) + 1:
                continue
            features = df_cleaned.iloc[:, all_sensor_cols].values.astype(np.float32)
            valid_indices = np.where(~np.isin(labels, [0]))[0]
            if len(valid_indices) == 0:
                continue
            features = features[valid_indices, :]
            labels = labels[valid_indices]
            if len(features) < window_size:
                continue
            start = 0
            while start + window_size <= len(features):
                window_data = features[start : start + window_size, :]
                window_labels_raw = labels[start : start + window_size]
                most_common_label = Counter(window_labels_raw).most_common(1)[0][0]
                all_windows.append(window_data)
                all_labels.append(most_common_label)
                start += step
        except:
            continue
    if not all_windows:
        return None, None, None
    pamap2_original_to_new = {
        1: 0, 2: 1, 3: 2, 4: 3, 5: 4, 12: 5,
        13: 6, 6: 7, 7: 8, 16: 9, 17: 10, 24: 11
    }
    pamap2_activity_names = [
        "Lying", "Sitting", "Standing", "Walking", "Running",
        "Ascending Stairs", "Descending Stairs", "Cycling",
        "Nordic Walking", "Vacuum Cleaning", "Ironing", "Rope Jumping"
    ]
    valid_mask = np.isin(all_labels, list(pamap2_original_to_new.keys()))
    if not np.any(valid_mask):
        return None, None, None
    filtered_windows = [all_windows[i] for i in range(len(all_windows)) if valid_mask[i]]
    filtered_labels = [all_labels[i] for i in range(len(all_labels)) if valid_mask[i]]
    mapped_labels = [pamap2_original_to_new[label] for label in filtered_labels]
    X_windowed = np.array(filtered_windows, dtype=np.float32)
    y_encoded = np.array(mapped_labels, dtype=int)
    scaler = MinMaxScaler()
    X_windowed_flat = X_windowed.reshape(X_windowed.shape[0], -1)
    X_windowed_flat = scaler.fit_transform(X_windowed_flat)
    X_windowed = X_windowed_flat.reshape(X_windowed.shape)
    X_windowed = np.transpose(X_windowed, (0, 2, 1))
    return X_windowed, y_encoded, pamap2_activity_names

class HARDataset(Dataset):
    def __init__(self, X, y, normalize=True):
        self.X = X.astype(np.float32)
        self.y = y.astype(np.int64)
        if normalize:
            self.mean = self.X.mean(axis=(0, 2), keepdims=True)
            self.std = self.X.std(axis=(0, 2), keepdims=True) + 1e-8
            self.X = (self.X - self.mean) / self.std
        else:
            self.mean, self.std = 0, 1

    def set_stats(self, mean, std):
        self.mean, self.std = mean, std
        self.X = (self.X - self.mean) / self.std

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return torch.from_numpy(self.X[idx]), int(self.y[idx])

class CompactEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.stage1 = self._make_stage(48, 16, stride=2)
        self.stage2 = self._make_stage(16, 32, stride=2)
        self.stage3 = self._make_stage(32, 64, stride=2)

    def _make_stage(self, in_ch, out_ch, stride=1):
        return nn.Sequential(
            nn.Conv1d(in_ch, out_ch, kernel_size=3, stride=stride, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.GELU(),
            nn.Conv1d(out_ch, out_ch, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.GELU(),
            nn.Conv1d(out_ch, out_ch, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.GELU()
        )

    def forward(self, x):
        x = self.stage1(x)
        x = self.stage2(x)
        x = self.stage3(x)
        return x

class CompactDecoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.stage1 = self._make_upsample(64, 32, output_padding=0)
        self.stage2 = self._make_upsample(32, 16, output_padding=1)
        self.stage3 = self._make_upsample(16, 48, output_padding=0)
        self.adjust_length = nn.Conv1d(48, 48, kernel_size=3, stride=1, padding=1)

    def _make_upsample(self, in_ch, out_ch, output_padding=0):
        return nn.Sequential(
            nn.ConvTranspose1d(in_ch, out_ch, kernel_size=4, stride=2, padding=1, output_padding=output_padding),
            nn.BatchNorm1d(out_ch),
            nn.GELU(),
            nn.Conv1d(out_ch, out_ch, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.GELU()
        )

    def forward(self, h):
        x = self.stage1(h)
        x = self.stage2(x)
        x = self.stage3(x)
        x = self.adjust_length(x)
        if x.size(-1) > 100:
            x = x[:, :, :100]
        elif x.size(-1) < 100:
            x = F.pad(x, (0, 100 - x.size(-1)))
        return x

class CausalManifoldHAR(nn.Module):
    def __init__(self, use_film=True, use_decoder=True):
        super().__init__()
        self.use_film = use_film
        self.use_decoder = use_decoder
        self.encoder = CompactEncoder()
        self.film = nn.Sequential(nn.Linear(6, 32), nn.GELU(), nn.Linear(32, 128)) if use_film else None
        self.to_Z = nn.Conv1d(64, 64, 1)
        self.to_N = nn.Conv1d(64, 64, 1)
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool1d(1),
            nn.Flatten(),
            nn.Linear(64, 128),
            nn.GELU(),
            nn.Dropout(0.1),
            nn.Linear(128, 64),
            nn.GELU(),
            nn.Dropout(0.1),
            nn.Linear(64, 12)
        )
        self.decoder = CompactDecoder() if use_decoder else None

    def forward(self, x, psi=None):
        h = self.encoder(x)
        if self.use_film and self.film is not None and psi is not None:
            params = self.film(psi).view(-1, 2, 64, 1)
            gamma, beta = params[:, 0], params[:, 1]
            h = h * gamma + beta
        h_z = self.to_Z(h)
        h_n = self.to_N(h)
        logits = self.classifier(h_z)
        x_recon = self.decoder(h_z + h_n) if self.use_decoder and self.decoder is not None else None
        return logits, h_z, h_n, x_recon

    def extract_features(self, x):
        h = self.encoder(x)
        if self.use_film and self.film is not None:
            psi = torch.zeros(x.shape[0], 6, device=x.device)
            params = self.film(psi).view(-1, 2, 64, 1)
            gamma, beta = params[:, 0], params[:, 1]
            h = h * gamma + beta
        return self.to_Z(h)

def extract_physics_features(x):
    B, C, T = x.shape
    features = []
    if C >= 3:
        acc = x[:, :3, :]
        gravity_dir = acc.mean(dim=-1)
        gravity_dir = F.normalize(gravity_dir, dim=1, eps=1e-8)
        features.append(gravity_dir)
    if C >= 3:
        acc = x[:, :3, :]
        jerk = torch.diff(acc, dim=-1)
        jerk_mag = jerk.norm(dim=1).mean(dim=-1, keepdim=True)
        features.append(jerk_mag)
    energy = (x ** 2).mean(dim=(1, 2)).unsqueeze(1)
    features.append(energy)
    x_fft = torch.fft.rfft(x, dim=-1)
    power = x_fft.abs() ** 2
    freq_bins = torch.arange(power.shape[-1], device=x.device).float()
    power_mean = power.mean(dim=1)
    freq_center = (power_mean * freq_bins).sum(dim=-1) / (power_mean.sum(dim=-1) + 1e-8)
    freq_center = freq_center.unsqueeze(1)
    features.append(freq_center)
    psi = torch.cat(features, dim=-1)
    return psi

class DoAugmentation:
    @staticmethod
    def apply_random_augmentation(x):
        x = x.clone()
        if torch.rand(1) < 0.5:
            angle = torch.rand(1) * 2 * 3.14159
            rot_matrix = torch.tensor([
                [torch.cos(angle), -torch.sin(angle), 0],
                [torch.sin(angle), torch.cos(angle), 0],
                [0, 0, 1]
            ], device=x.device, dtype=x.dtype)
            if x.shape[1] >= 3:
                acc = x[:, :3, :]
                acc_rot = torch.einsum('ij,bjt->bit', rot_matrix, acc)
                x = torch.cat([acc_rot, x[:, 3:, :]], dim=1)
        if torch.rand(1) < 0.5:
            noise = torch.randn_like(x) * 0.02
            x = x + noise
        if torch.rand(1) < 0.3:
            factor = torch.rand(1) * 0.4 + 0.8
            try:
                B, C, T = x.shape
                new_length = max(1, int(T * factor))
                x_reshaped = x.view(B * C, 1, T)
                x_resized = F.interpolate(x_reshaped, size=new_length, mode='linear', align_corners=False)
                x_resized = F.interpolate(x_resized, size=T, mode='linear', align_corners=False)
                x = x_resized.view(B, C, T)
            except:
                pass
        return x

class CausalHARLoss(nn.Module):
    def __init__(self, use_reconstruction=True, use_invariance=True, use_disentanglement=True):
        super().__init__()
        self.use_reconstruction = use_reconstruction
        self.use_invariance = use_invariance
        self.use_disentanglement = use_disentanglement
        self.ce = nn.CrossEntropyLoss()
        self.mse = nn.MSELoss()
        self.l1 = nn.L1Loss()

    def stft_loss(self, x, x_recon):
        try:
            B, C, T = x.shape
            x_flat = x.view(-1, T)
            x_recon_flat = x_recon.view(-1, T)
            n_fft = min(32, T//2)
            hop_length = n_fft // 2
            win_length = n_fft
            if n_fft < 4:
                return torch.tensor(0.0, device=x.device)
            window = torch.hann_window(win_length, device=x.device)
            x_stft = torch.stft(x_flat, n_fft=n_fft, hop_length=hop_length,
                               win_length=win_length, window=window,
                               return_complex=True, center=False)
            x_recon_stft = torch.stft(x_recon_flat, n_fft=n_fft, hop_length=hop_length,
                                     win_length=win_length, window=window,
                                     return_complex=True, center=False)
            return F.mse_loss(x_stft.abs(), x_recon_stft.abs())
        except:
            return torch.tensor(0.0, device=x.device)

    def hsic_loss(self, z, n, batch_size):
        try:
            z = z.view(batch_size, -1)
            n = n.view(batch_size, -1)
            z_norm = F.normalize(z, dim=1, eps=1e-8)
            n_norm = F.normalize(n, dim=1, eps=1e-8)
            Kz = torch.mm(z_norm, z_norm.t())
            Kn = torch.mm(n_norm, n_norm.t())
            H = torch.eye(batch_size, device=z.device) - 1.0 / batch_size
            hsic_value = torch.trace(torch.mm(torch.mm(Kz, H), torch.mm(Kn, H))) / ((batch_size - 1) ** 2)
            return hsic_value
        except:
            return torch.tensor(0.0, device=z.device)

    def forward(self, logits, y, x, x_recon=None, z=None, n=None, z_prime=None):
        ce_loss = self.ce(logits, y)
        rec_loss = torch.tensor(0.0, device=logits.device)
        if self.use_reconstruction and x_recon is not None:
            rec_loss = 0.5 * self.mse(x_recon, x) + 0.5 * self.stft_loss(x, x_recon)
        inv_loss = torch.tensor(0.0, device=logits.device)
        if self.use_invariance and z is not None and z_prime is not None:
            inv_loss = self.mse(z, z_prime)
        dis_loss = torch.tensor(0.0, device=logits.device)
        if self.use_disentanglement and z is not None and n is not None:
            batch_size = z.shape[0]
            dis_loss = self.hsic_loss(z, n, batch_size)
        total_loss = ce_loss + 0.1 * rec_loss + 0.1 * inv_loss + 0.01 * dis_loss
        return total_loss, ce_loss.item(), rec_loss.item(), inv_loss.item(), dis_loss.item()

def show_confusion_matrix(cm, class_names, title="Confusion Matrix"):
    try:
        cm_norm = cm.astype('float') / (cm.sum(axis=1)[:, np.newaxis] + 1e-8)
        df = pd.DataFrame(cm_norm, index=class_names, columns=class_names)
        annot = pd.DataFrame(cm, index=class_names, columns=class_names)
        plt.figure(figsize=(6, 6))
        sns.heatmap(df, annot=annot.values, fmt="", cmap="Blues", cbar=True,
                    annot_kws={"size": 9}, vmin=0, vmax=1)
        plt.xticks(rotation=90, fontsize=9)
        plt.yticks(rotation=0, fontsize=9)
        for spine in plt.gca().spines.values():
            spine.set_visible(True)
            spine.set_linewidth(0.5)
            spine.set_edgecolor('black')
        plt.xlabel('Predicted Label', fontsize=10)
        plt.ylabel('True Label', fontsize=10)
        plt.title(title, fontsize=12)
        plt.tight_layout()
        plt.show()
    except:
        pass

def plot_tsne(features, labels, activity_names, dataset_name="Dataset", samples_per_class=400):
    try:
        sampled_features, sampled_labels = [], []
        for i in range(len(activity_names)):
            class_mask = (labels == i)
            class_indices = np.where(class_mask)[0]
            if len(class_indices) > 0:
                if len(class_indices) >= samples_per_class:
                    selected_indices = np.random.choice(class_indices, samples_per_class, replace=False)
                else:
                    selected_indices = class_indices
                sampled_features.append(features[selected_indices])
                sampled_labels.append(labels[selected_indices])
        if not sampled_features:
            return
        features_sampled = np.vstack(sampled_features)
        labels_sampled = np.concatenate(sampled_labels)
        n_samples_total = features_sampled.shape[0]
        if n_samples_total <= 1:
            return
        current_perplexity = min(20, n_samples_total - 1)
        if current_perplexity < 5:
            return
        features_2d = TSNE(n_components=2, perplexity=current_perplexity, learning_rate=3000, random_state=42).fit_transform(features_sampled)
        colors = [
            "#FF0000", "#FFA500", "#FFFF00", "#008000", "#00FFFF", "#0000FF",
            "#800080", "#FFC0CB", "#A52A2A", "#000000", "#808080", "#FFD700"
        ]
        plt.figure(figsize=(6, 5))
        for i, activity in enumerate(activity_names):
            mask = (labels_sampled == i)
            if np.any(mask):
                plt.scatter(
                    features_2d[mask, 0], features_2d[mask, 1],
                    color=colors[i], marker='o', s=20, alpha=0.4
                )
        handles = [
            plt.Line2D([0], [0], marker='o', color='w', label=activity,
                       markerfacecolor=colors[i], markersize=7)
            for i, activity in enumerate(activity_names)
        ]
        plt.legend(handles=handles, title="Activities", fontsize=9, framealpha=1)
        plt.xlabel("t-SNE Component 1", fontsize=13)
        plt.ylabel("t-SNE Component 2", fontsize=13)
        plt.title(f"t-SNE - {dataset_name}", fontsize=13)
        plt.grid(False)
        plt.tight_layout()
        plt.show()
    except:
        pass

def compute_model_stats(model, input_shape=(48, 100)):
    try:
        device = next(model.parameters()).device
        dummy_input = torch.randn(1, *input_shape).to(device)
        model.eval()
        with torch.no_grad():
            classifier_original = model.classifier
            model.classifier = nn.Identity()
            macs_backbone, params_backbone = profile(model, inputs=(dummy_input,), verbose=False)
            model.classifier = classifier_original
            features = model.extract_features(dummy_input)
            macs_cls, params_cls = profile(model.classifier, inputs=(features,), verbose=False)
        total_macs_m = (macs_backbone + macs_cls) / 1e6
        total_params_m = (params_backbone + params_cls) / 1e6
        return total_params_m, total_macs_m
    except:
        return 0.0, 0.0

def measure_inference_time(model, input_size=(1, 48, 100), device='cuda', n_runs=100, warmup=10):
    try:
        model.eval()
        inputs = torch.randn(input_size).to(device)
        psi = torch.zeros(input_size[0], 6, device=device)
        with torch.inference_mode():
            for _ in range(warmup):
                _ = model(inputs, psi)
        if device == 'cuda' and torch.cuda.is_available():
            torch.cuda.synchronize()
        start = time.time()
        with torch.inference_mode():
            for _ in range(n_runs):
                _ = model(inputs, psi)
        if device == 'cuda' and torch.cuda.is_available():
            torch.cuda.synchronize()
        end = time.time()
        return (end - start) / n_runs * 1000
    except:
        return 0.0

class Trainer:
    def __init__(self, model, loss_fn, optimizer, scheduler, device, activity_names, save_dir):
        self.model = model.to(device)
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.scheduler = scheduler
        self.device = device
        self.activity_names = activity_names
        self.save_dir = save_dir
        os.makedirs(save_dir, exist_ok=True)
        self.best_f1 = 0
        self.best_metrics = {}

    def train_epoch(self, train_loader, val_loader, epoch):
        self.model.train()
        train_loss = 0
        train_correct = 0
        train_total = 0
        ce_losses = []
        rec_losses = []
        inv_losses = []
        dis_losses = []
        for batch_idx, (x, y) in enumerate(train_loader):
            try:
                x, y = x.to(self.device), y.to(self.device)
                psi = extract_physics_features(x)
                x_aug = DoAugmentation.apply_random_augmentation(x)
                psi_aug = extract_physics_features(x_aug)
                logits, z, n, x_recon = self.model(x, psi)
                _, z_prime, _, _ = self.model(x_aug, psi_aug)
                loss, ce, rec, inv, dis = self.self.loss_fn(logits, y, x, x_recon, z, n, z_prime)
                self.optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), 1.0)
                self.optimizer.step()
                self.scheduler.step()
                train_loss += loss.item()
                pred = logits.argmax(dim=1)
                train_correct += (pred == y).sum().item()
                train_total += y.size(0)
                ce_losses.append(ce)
                rec_losses.append(rec)
                inv_losses.append(inv)
                dis_losses.append(dis)
            except:
                continue
        train_acc = train_correct / max(train_total, 1)
        avg_train_loss = train_loss / max(len(train_loader), 1)
        self.model.eval()
        val_loss = 0
        val_correct = 0
        val_total = 0
        all_preds, all_labels, all_z = [], [], []
        with torch.no_grad():
            for batch_idx, (x, y) in enumerate(val_loader):
                try:
                    x, y = x.to(self.device), y.to(self.device)
                    psi = extract_physics_features(x)
                    logits, z, n, x_recon = self.model(x, psi)
                    loss, _, _, _, _ = self.loss_fn(logits, y, x, x_recon, z, n)
                    val_loss += loss.item()
                    pred = logits.argmax(dim=1)
                    val_correct += (pred == y).sum().item()
                    val_total += y.size(0)
                    all_preds.extend(pred.cpu().numpy())
                    all_labels.extend(y.cpu().numpy())
                    z_flat = z.view(z.size(0), -1).cpu().numpy()
                    all_z.extend(z_flat)
                except:
                    continue
        val_acc = val_correct / max(val_total, 1)
        avg_val_loss = val_loss / max(len(val_loader), 1)
        if all_preds and all_labels:
            f1_macro = f1_score(all_labels, all_preds, average='macro', zero_division=0)
            if f1_macro > self.best_f1:
                self.best_f1 = f1_macro
                self.best_metrics = {
                    'acc': val_acc,
                    'f1_macro': f1_macro,
                    'f1_weighted': f1_score(all_labels, all_preds, average='weighted', zero_division=0),
                    'precision': precision_score(all_labels, all_preds, average='macro', zero_division=0),
                    'recall': recall_score(all_labels, all_preds, average='macro', zero_division=0),
                    'params': compute_model_stats(self.model)[0],
                    'flops': compute_model_stats(self.model)[1],
                    'inf_ms': measure_inference_time(self.model, device=self.device),
                    'cm': confusion_matrix(all_labels, all_preds),
                    'z': np.array(all_z),
                    'preds': np.array(all_preds),
                    'labels': np.array(all_labels)
                }

    def get_best_results(self):
        return self.best_metrics

    def show_final_results(self, config_name):
        if not self.best_metrics:
            return
        print(f"\n{'='*50}")
        print(f"FINAL RESULTS FOR {config_name}")
        print(f"{'='*50}")
        print(f"Accuracy: {self.best_metrics['acc']:.4f}")
        print(f"F1 (macro): {self.best_metrics['f1_macro']:.4f}")
        print(f"F1 (weighted): {self.best_metrics['f1_weighted']:.4f}")
        print(f"Precision: {self.best_metrics['precision']:.4f}")
        print(f"Recall: {self.best_metrics['recall']:.4f}")
        print(f"Parameters (M): {self.best_metrics['params']:.2f}")
        print(f"FLOPs (M): {self.best_metrics['flops']:.2f}")
        print(f"Inference (ms): {self.best_metrics['inf_ms']:.2f}")
        print(f"\nConfusion Matrix for {config_name}:")
        show_confusion_matrix(self.best_metrics['cm'], self.activity_names,
                             f"Confusion Matrix - {config_name}")
        print(f"\nt-SNE Visualization for {config_name}:")
        plot_tsne(self.best_metrics['z'], self.best_metrics['labels'],
                 self.activity_names, config_name, samples_per_class=400)

class RobustnessTests:
    @staticmethod
    def apply_rotation(x_batch, degrees):
        try:
            device = x_batch.device
            dtype = x_batch.dtype
            rad = torch.tensor(degrees * np.pi / 180.0, device=device, dtype=dtype)
            axis = F.normalize(torch.rand(3, device=device, dtype=dtype), dim=0)
            K = torch.zeros((3, 3), device=device, dtype=dtype)
            K[0, 1] = -axis[2]
            K[0, 2] = axis[1]
            K[1, 0] = axis[2]
            K[1, 2] = -axis[0]
            K[2, 0] = -axis[1]
            K[2, 1] = axis[0]
            cos_rad = torch.cos(rad)
            sin_rad = torch.sin(rad)
            I = torch.eye(3, device=device, dtype=dtype)
            R = I + sin_rad * K + (1 - cos_rad) * torch.mm(K, K)
            x_aug_list = []
            if x_batch.shape[1] >= 3:
                x_aug_list.append(torch.einsum('ij,bjt->bit', R, x_batch[:, 0:3, :]))
            if x_batch.shape[1] >= 6:
                x_aug_list.append(torch.einsum('ij,bjt->bit', R, x_batch[:, 3:6, :]))
            if x_batch.shape[1] >= 9:
                x_aug_list.append(torch.einsum('ij,bjt->bit', R, x_batch[:, 6:9, :]))
            if x_batch.shape[1] > 9:
                x_aug_list.append(x_batch[:, 9:, :])
            return torch.cat(x_aug_list, dim=1)
        except:
            return x_batch

    @staticmethod
    def apply_gaussian_noise(x_batch, percentage):
        try:
            noise_std = (percentage / 100.0) * torch.std(x_batch)
            noise = torch.randn_like(x_batch) * noise_std
            return x_batch + noise
        except:
            return x_batch

    @staticmethod
    def apply_elimination(x_batch, percentage):
        try:
            B, C, T = x_batch.shape
            num_to_zero = int(T * (percentage / 100.0))
            if num_to_zero == 0:
                return x_batch
            indices = torch.stack([torch.randperm(T, device=x_batch.device)[:num_to_zero] for _ in range(B)])
            x_aug = x_batch.clone()
            batch_indices = torch.arange(B, device=x_batch.device).view(-1, 1).expand_as(indices)
            x_aug[batch_indices, :, indices] = 0.0
            return x_aug
        except:
            return x_batch

    @staticmethod
    def apply_scaling(x_batch, percentage):
        try:
            factor = 1.0 + (percentage / 100.0)
            return x_batch * factor
        except:
            return x_batch

    @staticmethod
    def apply_time_warping(x_batch, percentage):
        try:
            B, C, T = x_batch.shape
            factor = 1.0 + (torch.rand(1).item() * (percentage / 100.0) * 2) - (percentage / 100.0)
            new_length = max(1, int(T * factor))
            if new_length == T:
                return x_batch
            x_reshaped = x_batch.view(B * C, 1, T)
            x_resized = F.interpolate(x_reshaped, size=new_length, mode='linear', align_corners=False)
            x_resized = F.interpolate(x_resized, size=T, mode='linear', align_corners=False)
            return x_resized.view(B, C, T)
        except:
            return x_batch

    @staticmethod
    def apply_freq_masking(x_batch, percentage):
        try:
            B, C, T = x_batch.shape
            x_fft = torch.fft.rfft(x_batch, dim=-1)
            n_freqs = x_fft.shape[-1]
            mask_width = int(n_freqs * (percentage / 100.0))
            if mask_width == 0:
                return x_batch
            mask_start = torch.randint(0, n_freqs - mask_width + 1, (B, C), device=x_batch.device)
            mask_indices = torch.arange(n_freqs, device=x_batch.device).view(1, 1, -1)
            mask = (mask_indices >= mask_start.unsqueeze(-1)) & (mask_indices < (mask_start + mask_width).unsqueeze(-1))
            x_fft_masked = x_fft.masked_fill(mask, 0)
            return torch.fft.irfft(x_fft_masked, n=T, dim=-1)
        except:
            return x_batch

    @staticmethod
    def apply_freq_filtering(x_batch, percentage):
        try:
            B, C, T = x_batch.shape
            x_fft = torch.fft.rfft(x_batch, dim=-1)
            n_freqs = x_fft.shape[-1]
            keep_width = int(n_freqs * (percentage / 100.0))
            if keep_width == 0:
                return torch.zeros_like(x_batch)
            if keep_width >= n_freqs:
                return x_batch
            keep_start = torch.randint(0, n_freqs - keep_width + 1, (B, C), device=x_batch.device)
            mask_indices = torch.arange(n_freqs, device=x_batch.device).view(1, 1, -1)
            mask = (mask_indices < keep_start.unsqueeze(-1)) | (mask_indices >= (keep_start + keep_width).unsqueeze(-1))
            x_fft_filtered = x_fft.masked_fill(mask, 0)
            return torch.fft.irfft(x_fft_filtered, n=T, dim=-1)
        except:
            return x_batch

def run_robustness_evaluation(trained_models_map, device, activity_names):
    robustness_results = []
    test_scenarios = [
        ("Rotation", [5, 10, 15, 20, 25], RobustnessTests.apply_rotation),
        ("Gaussian Noise", [5, 10, 15, 20, 25], RobustnessTests.apply_gaussian_noise),
        ("Elimination", [5, 10, 15, 20, 25], RobustnessTests.apply_elimination),
        ("Scaling", [5, 10, 15, 20, 25], RobustnessTests.apply_scaling),
        ("Time Warping", [5, 10, 15, 20, 25], RobustnessTests.apply_time_warping),
        ("Freq Masking", [5, 10, 15, 20, 25], RobustnessTests.apply_freq_masking),
        ("Freq Filtering", [5, 10, 15, 20, 25], RobustnessTests.apply_freq_filtering)
    ]

    for name, (model, test_dataset) in trained_models_map.items():
        test_loader = DataLoader(test_dataset, batch_size=512, shuffle=False, num_workers=2, pin_memory=True)
        model.eval()
        for test_name, intensities, aug_fn in test_scenarios:
            for intensity in intensities:
                with torch.no_grad():
                    all_preds = []
                    all_labels = []
                    for x_batch, y_batch in test_loader:
                        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
                        x_aug = aug_fn(x_batch.clone(), intensity)
                        psi_aug = extract_physics_features(x_aug)
                        logits, _, _, _ = model(x_aug, psi_aug)
                        preds = logits.argmax(dim=1)
                        all_preds.append(preds.cpu())
                        all_labels.append(y_batch.cpu())
                    all_preds_np = torch.cat(all_preds).numpy()
                    all_labels_np = torch.cat(all_labels).numpy()
                    acc = accuracy_score(all_labels_np, all_preds_np)
                    f1 = f1_score(all_labels_np, all_preds_np, average='macro', zero_division=0)
                    robustness_results.append({
                        "Model": name,
                        "Test": test_name,
                        "Intensity": f"{intensity}°" if test_name == "Rotation" else f"{intensity}%",
                        "Acc": round(acc, 4),
                        "F1": round(f1, 4)
                    })
    test_df = pd.DataFrame(robustness_results)
    display(test_df)
    display(test_df.pivot_table(index=["Test", "Intensity"], columns="Model", values="Acc"))
    display(test_df.pivot_table(index=["Test", "Intensity"], columns="Model", values="F1"))

def run_ablation_study(data_root=None):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    if data_root is None:
        data_root = "./PAMAP2_Dataset"
        if not os.path.exists(data_root):
            try:
                from google.colab import drive
                drive.mount('/content/drive')
                data_root = "/content/drive/MyDrive/PAMAP2_Dataset"
                if not os.path.exists(data_root):
                    return
            except ImportError:
                return
    try:
        X_data, y_data, activity_names = load_pamap2_data(dataset_dir=data_root)
        if X_data is None or y_data is None:
            return
        indices = np.arange(len(y_data))
        np.random.shuffle(indices)
        val_size = int(0.2 * len(y_data))
        test_size = int(0.2 * len(y_data))
        train_size = len(y_data) - val_size - test_size
        train_idx = indices[:train_size]
        val_idx = indices[train_size:train_size + val_size]
        test_idx = indices[train_size + val_size:]
        X_train_orig = X_data[train_idx]
        y_train_orig = y_data[train_idx]
        X_val_split = X_data[val_idx]
        y_val_split = y_data[val_idx]
        X_test_raw = X_data[test_idx]
        y_test_raw = y_data[test_idx]
        configs = [
            ("Full", True, True, True, True),
            ("w_o_FiLM", False, True, True, True),
            ("w_o_Inv", True, True, False, True),
            ("w_o_Dis", True, True, True, False),
            ("w_o_Dec", True, False, True, True),
            ("Baseline", False, False, False, False),
        ]
        results = []
        trained_models_map = {}
        for name, use_film, use_decoder, use_inv, use_dis in configs:
            save_dir = f"./results/{name}"
            os.makedirs(save_dir, exist_ok=True)
            train_dataset = HARDataset(X_train_orig, y_train_orig, normalize=True)
            mean, std = train_dataset.mean, train_dataset.std
            val_dataset = HARDataset(X_val_split, y_val_split, normalize=False)
            val_dataset.set_stats(mean, std)
            test_dataset = HARDataset(X_test_raw, y_test_raw, normalize=False)
            test_dataset.set_stats(mean, std)
            train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True, num_workers=2, pin_memory=True, drop_last=True)
            val_loader = DataLoader(val_dataset, batch_size=512, shuffle=False, num_workers=2, pin_memory=True)
            test_loader = DataLoader(test_dataset, batch_size=512, shuffle=False, num_workers=2, pin_memory=True)
            try:
                model = CausalManifoldHAR(use_film=use_film, use_decoder=use_decoder)
                loss_fn = CausalHARLoss(use_reconstruction=use_decoder, use_invariance=use_inv, use_disentanglement=use_dis)
                optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-5)
                scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)
                trainer = Trainer(model, loss_fn, optimizer, scheduler, device, activity_names, save_dir)
                for epoch in range(1, 201):
                    trainer.train_epoch(train_loader, val_loader, epoch)
                model.eval()
                all_preds, all_labels, all_z = [], [], []
                test_loss = 0
                test_correct = 0
                test_total = 0
                with torch.no_grad():
                    for x, y in test_loader:
                        x, y = x.to(device), y.to(device)
                        psi = extract_physics_features(x)
                        logits, z, n, x_recon = model(x, psi)
                        loss, _, _, _, _ = loss_fn(logits, y, x, x_recon, z, n)
                        test_loss += loss.item()
                        pred = logits.argmax(dim=1)
                        test_correct += (pred == y).sum().item()
                        test_total += y.size(0)
                        all_preds.extend(pred.cpu().numpy())
                        all_labels.extend(y.cpu().numpy())
                        z_flat = z.view(z.size(0), -1).cpu().numpy()
                        all_z.extend(z_flat)
                if test_total == 0:
                    continue
                test_acc = test_correct / test_total
                f1_macro = f1_score(all_labels, all_preds, average='macro', zero_division=0)
                f1_weighted = f1_score(all_labels, all_preds, average='weighted', zero_division=0)
                precision = precision_score(all_labels, all_preds, average='macro', zero_division=0)
                recall = recall_score(all_labels, all_preds, average='macro', zero_division=0)
                cm = confusion_matrix(all_labels, all_preds)
                best_metrics = {
                    'acc': test_acc,
                    'f1_macro': f1_macro,
                    'f1_weighted': f1_weighted,
                    'precision': precision,
                    'recall': recall,
                    'params': compute_model_stats(model)[0],
                    'flops': compute_model_stats(model)[1],
                    'inf_ms': measure_inference_time(model, device=device),
                    'cm': cm,
                    'z': np.array(all_z),
                    'preds': np.array(all_preds),
                    'labels': np.array(all_labels)
                }
                results.append({
                    'Config': name,
                    'F1(m)': round(f1_macro, 4),
                    'Acc': round(test_acc, 4),
                    'Prec': round(precision, 4),
                    'Rec': round(recall, 4),
                    'Params(M)': round(best_metrics['params'], 2),
                    'FLOPs(M)': round(best_metrics['flops'], 2),
                    'Inf(ms)': round(best_metrics['inf_ms'], 2),
                })
                trainer.best_metrics = best_metrics
                trainer.best_f1 = f1_macro
                trainer.show_final_results(name)
                if name in ["Full", "Baseline"]:
                    trained_models_map[name] = (model, test_dataset)
            except:
                continue
        if results:
            rst_df = pd.DataFrame(results)
            display(rst_df)
        if "Full" in trained_models_map and "Baseline" in trained_models_map:
            run_robustness_evaluation(trained_models_map, device, activity_names)
    except:
        pass

if __name__ == "__main__":
    run_ablation_study(data_root=None)
# Out:
# <>:50: SyntaxWarning: invalid escape sequence '\s'
# <>:50: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-2832062707.py:50: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(file_path, sep='\s+', header=None, na_values='NaN')
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Collecting ptflops
#   Downloading ptflops-0.7.5-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from thop) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->thop) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->thop) (3.0.3)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading ptflops-0.7.5-py3-none-any.whl (19 kB)
# Installing collected packages: thop, ptflops
# Successfully installed ptflops-0.7.5 thop-0.1.1.post2209072238
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading PAMAP2 dataset...
# Found 14 subject files. Processing...
#   Processing subject101...
#     subject101: Loaded dataframe with shape (376417, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject101: Shape after NaN interpolation: (376417, 54)
#     subject101: Created 4998 windows
#   Processing subject102...
#     subject102: Loaded dataframe with shape (447000, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject102: Shape after NaN interpolation: (447000, 54)
#     subject102: Created 10263 windows
#   Processing subject103...
#     subject103: Loaded dataframe with shape (252833, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject103: Shape after NaN interpolation: (252833, 54)
#     subject103: Created 13748 windows
#   Processing subject104...
#     subject104: Loaded dataframe with shape (329576, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject104: Shape after NaN interpolation: (329576, 54)
#     subject104: Created 18375 windows
#   Processing subject105...
#     subject105: Loaded dataframe with shape (374783, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject105: Shape after NaN interpolation: (374783, 54)
#     subject105: Created 23822 windows
#   Processing subject106...
#     subject106: Loaded dataframe with shape (361817, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject106: Shape after NaN interpolation: (361817, 54)
#     subject106: Created 28822 windows
#   Processing subject107...
#     subject107: Loaded dataframe with shape (313599, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject107: Shape after NaN interpolation: (313599, 54)
#     subject107: Created 33476 windows
#   Processing subject108...
#     subject108: Loaded dataframe with shape (408031, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject108: Shape after NaN interpolation: (408031, 54)
#     subject108: Created 38717 windows
#   Processing subject109...
#     subject109: Loaded dataframe with shape (8477, 54)
#     subject109: Shape after NaN interpolation: (8477, 54)
#     subject109: Created 38843 windows
#   Processing subject101...
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject101: Loaded dataframe with shape (319352, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject101: Shape after NaN interpolation: (319352, 54)
#     subject101: Created 43229 windows
#   Processing subject105...
#     subject105: Loaded dataframe with shape (154773, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject105: Shape after NaN interpolation: (154773, 54)
#     subject105: Created 46015 windows
#   Processing subject106...
#     subject106: Loaded dataframe with shape (129963, 54)
#     subject106: Shape after NaN interpolation: (129963, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject106: Created 48259 windows
#   Processing subject108...
#     subject108: Loaded dataframe with shape (180412, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject108: Shape after NaN interpolation: (180412, 54)
#     subject108: Created 51301 windows
#   Processing subject109...
#     subject109: Loaded dataframe with shape (193472, 54)
# /tmp/ipython-input-2832062707.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df.fillna(method='ffill').fillna(method='bfill')
#     subject109: Shape after NaN interpolation: (193472, 54)
#     subject109: Created 54477 windows
# PAMAP2 - X_sequences shape: (38843, 48, 100)
#
# ==================================================
# FINAL RESULTS FOR Full
# ==================================================
# Accuracy: 0.9719
# F1 (macro): 0.9676
# F1 (weighted): 0.9719
# Precision: 0.9680
# Recall: 0.9675
# Parameters (M): 0.10
# FLOPs (M): 3.22
# Inference (ms): 2.29
#
# Confusion Matrix for Full:
# t-SNE Visualization for Full:
# ==================================================
# FINAL RESULTS FOR w_o_FiLM
# ==================================================
# Accuracy: 0.9547
# F1 (macro): 0.9482
# F1 (weighted): 0.9546
# Precision: 0.9505
# Recall: 0.9462
# Parameters (M): 0.10
# FLOPs (M): 3.22
# Inference (ms): 1.96
#
# Confusion Matrix for w_o_FiLM:
# t-SNE Visualization for w_o_FiLM:
# ==================================================
# FINAL RESULTS FOR w_o_Inv
# ==================================================
# Accuracy: 0.9516
# F1 (macro): 0.9435
# F1 (weighted): 0.9516
# Precision: 0.9433
# Recall: 0.9440
# Parameters (M): 0.10
# FLOPs (M): 3.22
# Inference (ms): 2.30
#
# Confusion Matrix for w_o_Inv:
# t-SNE Visualization for w_o_Inv:
# ==================================================
# FINAL RESULTS FOR w_o_Dis
# ==================================================
# Accuracy: 0.9661
# F1 (macro): 0.9603
# F1 (weighted): 0.9661
# Precision: 0.9601
# Recall: 0.9606
# Parameters (M): 0.10
# FLOPs (M): 3.22
# Inference (ms): 2.51
#
# Confusion Matrix for w_o_Dis:
# t-SNE Visualization for w_o_Dis:
# ==================================================
# FINAL RESULTS FOR w_o_Dec
# ==================================================
# Accuracy: 0.9641
# F1 (macro): 0.9594
# F1 (weighted): 0.9641
# Precision: 0.9604
# Recall: 0.9585
# Parameters (M): 0.07
# FLOPs (M): 0.94
# Inference (ms): 1.37
#
# Confusion Matrix for w_o_Dec:
# t-SNE Visualization for w_o_Dec:
# ==================================================
# FINAL RESULTS FOR Baseline
# ==================================================
# Accuracy: 0.9553
# F1 (macro): 0.9471
# F1 (weighted): 0.9555
# Precision: 0.9486
# Recall: 0.9462
# Parameters (M): 0.07
# FLOPs (M): 0.94
# Inference (ms): 1.30
#
# Confusion Matrix for Baseline:
# t-SNE Visualization for Baseline:
#      Config   F1(m)     Acc    Prec     Rec  Params(M)  FLOPs(M)  Inf(ms)
# 0      Full  0.9676  0.9719  0.9680  0.9675       0.10      3.22     2.29
# 1  w_o_FiLM  0.9482  0.9547  0.9505  0.9462       0.10      3.22     1.96
# 2   w_o_Inv  0.9435  0.9516  0.9433  0.9440       0.10      3.22     2.30
# 3   w_o_Dis  0.9603  0.9661  0.9601  0.9606       0.10      3.22     2.51
# 4   w_o_Dec  0.9594  0.9641  0.9604  0.9585       0.07      0.94     1.37
# 5  Baseline  0.9471  0.9553  0.9486  0.9462       0.07      0.94     1.30
#        Model            Test Intensity     Acc      F1
# 0       Full        Rotation        5°  0.9723  0.9679
# 1       Full        Rotation       10°  0.9723  0.9681
# 2       Full        Rotation       15°  0.9710  0.9669
# 3       Full        Rotation       20°  0.9692  0.9654
# 4       Full        Rotation       25°  0.9678  0.9639
# 5       Full  Gaussian Noise        5%  0.9722  0.9680
# 6       Full  Gaussian Noise       10%  0.9723  0.9683
# 7       Full  Gaussian Noise       15%  0.9709  0.9671
# 8       Full  Gaussian Noise       20%  0.9688  0.9650
# 9       Full  Gaussian Noise       25%  0.9667  0.9624
# 10      Full     Elimination        5%  0.9721  0.9682
# 11      Full     Elimination       10%  0.9652  0.9605
# 12      Full     Elimination       15%  0.9569  0.9509
# 13      Full     Elimination       20%  0.9418  0.9333
# 14      Full     Elimination       25%  0.9221  0.9110
# 15      Full         Scaling        5%  0.9721  0.9681
# 16      Full         Scaling       10%  0.9694  0.9654
# 17      Full         Scaling       15%  0.9660  0.9617
# 18      Full         Scaling       20%  0.9564  0.9520
# 19      Full         Scaling       25%  0.9385  0.9339
# 20      Full    Time Warping        5%  0.9672  0.9640
# 21      Full    Time Warping       10%  0.9628  0.9591
# 22      Full    Time Warping       15%  0.9642  0.9606
# 23      Full    Time Warping       20%  0.9624  0.9592
# 24      Full    Time Warping       25%  0.9650  0.9612
# 25      Full    Freq Masking        5%  0.9631  0.9588
# 26      Full    Freq Masking       10%  0.9574  0.9501
# 27      Full    Freq Masking       15%  0.9546  0.9474
# 28      Full    Freq Masking       20%  0.9501  0.9421
# 29      Full    Freq Masking       25%  0.9461  0.9409
# 30      Full  Freq Filtering        5%  0.1074  0.0327
# 31      Full  Freq Filtering       10%  0.1110  0.0328
# 32      Full  Freq Filtering       15%  0.1084  0.0345
# 33      Full  Freq Filtering       20%  0.1090  0.0392
# 34      Full  Freq Filtering       25%  0.1137  0.0429
# 35  Baseline        Rotation        5°  0.9558  0.9473
# 36  Baseline        Rotation       10°  0.9546  0.9465
# 37  Baseline        Rotation       15°  0.9529  0.9448
# 38  Baseline        Rotation       20°  0.9502  0.9421
# 39  Baseline        Rotation       25°  0.9475  0.9382
# 40  Baseline  Gaussian Noise        5%  0.9544  0.9466
# 41  Baseline  Gaussian Noise       10%  0.9538  0.9457
# 42  Baseline  Gaussian Noise       15%  0.9517  0.9440
# 43  Baseline  Gaussian Noise       20%  0.9475  0.9388
# 44  Baseline  Gaussian Noise       25%  0.9408  0.9312
# 45  Baseline     Elimination        5%  0.9507  0.9428
# 46  Baseline     Elimination       10%  0.9377  0.9290
# 47  Baseline     Elimination       15%  0.9222  0.9109
# 48  Baseline     Elimination       20%  0.8939  0.8810
# 49  Baseline     Elimination       25%  0.8606  0.8391
# 50  Baseline         Scaling        5%  0.9524  0.9434
# 51  Baseline         Scaling       10%  0.9489  0.9406
# 52  Baseline         Scaling       15%  0.9427  0.9327
# 53  Baseline         Scaling       20%  0.9338  0.9228
# 54  Baseline         Scaling       25%  0.9224  0.9100
# 55  Baseline    Time Warping        5%  0.9446  0.9379
# 56  Baseline    Time Warping       10%  0.9440  0.9368
# 57  Baseline    Time Warping       15%  0.9435  0.9366
# 58  Baseline    Time Warping       20%  0.9403  0.9334
# 59  Baseline    Time Warping       25%  0.9408  0.9340
# 60  Baseline    Freq Masking        5%  0.9365  0.9297
# 61  Baseline    Freq Masking       10%  0.9261  0.9164
# 62  Baseline    Freq Masking       15%  0.9274  0.9184
# 63  Baseline    Freq Masking       20%  0.9162  0.9076
# 64  Baseline    Freq Masking       25%  0.9091  0.8993
# 65  Baseline  Freq Filtering        5%  0.0924  0.0649
# 66  Baseline  Freq Filtering       10%  0.1040  0.0699
# 67  Baseline  Freq Filtering       15%  0.1071  0.0733
# 68  Baseline  Freq Filtering       20%  0.1114  0.0779
# 69  Baseline  Freq Filtering       25%  0.1134  0.0755
# Model                     Baseline    Full
# Test           Intensity
# Elimination    10%          0.9377  0.9652
#                15%          0.9222  0.9569
#                20%          0.8939  0.9418
#                25%          0.8606  0.9221
#                5%           0.9507  0.9721
# Freq Filtering 10%          0.1040  0.1110
#                15%          0.1071  0.1084
#                20%          0.1114  0.1090
#                25%          0.1134  0.1137
#                5%           0.0924  0.1074
# Freq Masking   10%          0.9261  0.9574
#                15%          0.9274  0.9546
#                20%          0.9162  0.9501
#                25%          0.9091  0.9461
#                5%           0.9365  0.9631
# Gaussian Noise 10%          0.9538  0.9723
#                15%          0.9517  0.9709
#                20%          0.9475  0.9688
#                25%          0.9408  0.9667
#                5%           0.9544  0.9722
# Rotation       10°          0.9546  0.9723
#                15°          0.9529  0.9710
#                20°          0.9502  0.9692
#                25°          0.9475  0.9678
#                5°           0.9558  0.9723
# Scaling        10%          0.9489  0.9694
#                15%          0.9427  0.9660
#                20%          0.9338  0.9564
#                25%          0.9224  0.9385
#                5%           0.9524  0.9721
# Time Warping   10%          0.9440  0.9628
#                15%          0.9435  0.9642
#                20%          0.9403  0.9624
#                25%          0.9408  0.9650
#                5%           0.9446  0.9672
# Model                     Baseline    Full
# Test           Intensity
# Elimination    10%          0.9290  0.9605
#                15%          0.9109  0.9509
#                20%          0.8810  0.9333
#                25%          0.8391  0.9110
#                5%           0.9428  0.9682
# Freq Filtering 10%          0.0699  0.0328
#                15%          0.0733  0.0345
#                20%          0.0779  0.0392
#                25%          0.0755  0.0429
#                5%           0.0649  0.0327
# Freq Masking   10%          0.9164  0.9501
#                15%          0.9184  0.9474
#                20%          0.9076  0.9421
#                25%          0.8993  0.9409
#                5%           0.9297  0.9588
# Gaussian Noise 10%          0.9457  0.9683
#                15%          0.9440  0.9671
#                20%          0.9388  0.9650
#                25%          0.9312  0.9624
#                5%           0.9466  0.9680
# Rotation       10°          0.9465  0.9681
#                15°          0.9448  0.9669
#                20°          0.9421  0.9654
#                25°          0.9382  0.9639
#                5°           0.9473  0.9679
# Scaling        10%          0.9406  0.9654
#                15%          0.9327  0.9617
#                20%          0.9228  0.9520
#                25%          0.9100  0.9339
#                5%           0.9434  0.9681
# Time Warping   10%          0.9368  0.9591
#                15%          0.9366  0.9606
#                20%          0.9334  0.9592
#                25%          0.9340  0.9612
#                5%           0.9379  0.9640
