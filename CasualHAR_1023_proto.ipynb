# %%
pip install thop ptflops
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Collecting ptflops
#   Downloading ptflops-0.7.5-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from thop) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->thop) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->thop) (3.0.3)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading ptflops-0.7.5-py3-none-any.whl (19 kB)
# Installing collected packages: thop, ptflops
# Successfully installed ptflops-0.7.5 thop-0.1.1.post2209072238

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from sklearn.manifold import TSNE
from IPython.display import display
from thop import profile

def set_seed(seed: int = 42):
    import random
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

set_seed(42)

def read_txt_matrix(file_path):
    try:
        return np.loadtxt(file_path, dtype=np.float32)
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        raise

def load_full_uci_har_data(root: str):
    if not os.path.exists(root):
        raise FileNotFoundError(f"Data directory not found: {root}")

    UCI_CHANNELS_PREFIX = [
        "total_acc_x_", "total_acc_y_", "total_acc_z_",
        "body_acc_x_", "body_acc_y_", "body_acc_z_",
        "body_gyro_x_", "body_gyro_y_", "body_gyro_z_",
    ]

    def load_split(split):
        channels = []
        for prefix in UCI_CHANNELS_PREFIX:
            file_path = os.path.join(root, f"{prefix}{split}.txt")
            if not os.path.exists(file_path):
                raise FileNotFoundError(f"File not found: {file_path}")
            channels.append(read_txt_matrix(file_path))

        X = np.stack(channels, axis=1)
        y = read_txt_matrix(os.path.join(root, f"y_{split}.txt")).astype(int) - 1
        subjects = read_txt_matrix(os.path.join(root, f"subject_{split}.txt")).astype(int)
        return X, y, subjects

    X_train, y_train, subjects_train = load_split("train")
    X_test, y_test, subjects_test = load_split("test")
    X_all = np.concatenate((X_train, X_test), axis=0)
    y_all = np.concatenate((y_train, y_test), axis=0)
    subjects_all = np.concatenate((subjects_train, subjects_test), axis=0)
    sorted_indices = np.argsort(subjects_all)
    X_all, y_all, subjects_all = X_all[sorted_indices], y_all[sorted_indices], subjects_all[sorted_indices]
    activity_names = ['Walking', 'Walking Upstairs', 'Walking Downstairs', 'Sitting', 'Standing', 'Laying']
    print(f"Loaded all data: X={X_all.shape}, y={y_all.shape}, Subjects={len(np.unique(subjects_all))}")
    return X_all, y_all, subjects_all, activity_names

class HARDataset(Dataset):
    def __init__(self, X, y, normalize=True):
        self.X = X.astype(np.float32)
        self.y = y.astype(np.int64)
        if normalize:
            self.mean = self.X.mean(axis=(0, 2), keepdims=True)
            self.std = self.X.std(axis=(0, 2), keepdims=True) + 1e-8
            self.X = (self.X - self.mean) / self.std
        else:
            self.mean, self.std = 0, 1

    def set_stats(self, mean, std):
        self.mean, self.std = mean, std
        self.X = (self.X - self.mean) / self.std

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return torch.from_numpy(self.X[idx]), int(self.y[idx])

class SimpleCNNBlock(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv = nn.Conv1d(9, 128, kernel_size=3, padding=1)
        self.bn = nn.BatchNorm1d(128)
        self.act = nn.GELU()
        self.pool = nn.AdaptiveAvgPool1d(128)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.act(x)
        x = self.pool(x)
        return x

class CausalManifoldHAR(nn.Module):
    def __init__(self, use_film=True, use_decoder=True):
        super().__init__()
        self.use_film = use_film
        self.use_decoder = use_decoder
        self.embed = SimpleCNNBlock()
        self.film = nn.Sequential(nn.Linear(6, 64), nn.GELU(), nn.Linear(64, 256)) if use_film else None
        self.to_Z = nn.Conv1d(128, 128, 1)
        self.to_N = nn.Conv1d(128, 128, 1)
        self.classifier = nn.Sequential(nn.AdaptiveAvgPool1d(1), nn.Flatten(), nn.Linear(128, 6))
        self.decoder = nn.Sequential(
            nn.Conv1d(128, 128, 3, padding=1), nn.BatchNorm1d(128), nn.GELU(),
            nn.Conv1d(128, 64, 3, padding=1), nn.BatchNorm1d(64), nn.GELU(),
            nn.Conv1d(64, 9, 3, padding=1)
        ) if use_decoder else None

    def forward(self, x, psi=None):
        h = self.embed(x)
        if self.use_film and self.film is not None and psi is not None:
            params = self.film(psi).view(-1, 2, 128, 1)
            gamma, beta = params[:, 0], params[:, 1]
            h = h * gamma + beta
        h_z = self.to_Z(h)
        h_n = self.to_N(h)
        logits = self.classifier(h_z)
        x_recon = self.decoder(h_z + h_n) if self.use_decoder and self.decoder is not None else None
        return logits, h_z, h_n, x_recon

    def extract_features(self, x):
        h = self.embed(x)
        if self.use_film and self.film is not None:
            psi = torch.zeros(x.shape[0], 6, device=x.device)
            params = self.film(psi).view(-1, 2, 128, 1)
            gamma, beta = params[:, 0], params[:, 1]
            h = h * gamma + beta
        return self.to_Z(h)

def extract_physics_features(x):
    B, C, T = x.shape
    features = []

    if C >= 3:
        acc = x[:, :3, :]
        gravity_dir = acc.mean(dim=-1)
        gravity_dir = F.normalize(gravity_dir, dim=1, eps=1e-8)
        features.append(gravity_dir)

    if C >= 3:
        acc = x[:, :3, :]
        jerk = torch.diff(acc, dim=-1)
        jerk_mag = jerk.norm(dim=1).mean(dim=-1, keepdim=True)
        features.append(jerk_mag)

    energy = (x ** 2).mean(dim=(1, 2)).unsqueeze(1)
    features.append(energy)

    x_fft = torch.fft.rfft(x, dim=-1)
    power = x_fft.abs() ** 2
    freq_bins = torch.arange(power.shape[-1], device=x.device).float()
    power_mean = power.mean(dim=1)
    freq_center = (power_mean * freq_bins).sum(dim=-1) / (power_mean.sum(dim=-1) + 1e-8)
    freq_center = freq_center.unsqueeze(1)
    features.append(freq_center)

    psi = torch.cat(features, dim=-1)
    return psi

class DoAugmentation:
    @staticmethod
    def apply_random_augmentation(x):
        x = x.clone()

        if torch.rand(1) < 0.5:
            angle = torch.rand(1) * 2 * 3.14159
            rot_matrix = torch.tensor([
                [torch.cos(angle), -torch.sin(angle), 0],
                [torch.sin(angle), torch.cos(angle), 0],
                [0, 0, 1]
            ], device=x.device, dtype=x.dtype)
            if x.shape[1] >= 3:
                acc = x[:, :3, :]
                acc_rot = torch.einsum('ij,bjt->bit', rot_matrix, acc)
                x = torch.cat([acc_rot, x[:, 3:, :]], dim=1)

        if torch.rand(1) < 0.5:
            noise = torch.randn_like(x) * 0.02
            x = x + noise

        if torch.rand(1) < 0.3:
            factor = torch.rand(1) * 0.4 + 0.8
            try:
                B, C, T = x.shape
                new_length = max(1, int(T * factor))
                x_reshaped = x.view(B * C, 1, T)
                x_resized = F.interpolate(x_reshaped, size=new_length, mode='linear', align_corners=False)
                x_resized = F.interpolate(x_resized, size=T, mode='linear', align_corners=False)
                x = x_resized.view(B, C, T)
            except:
                pass

        return x

class CausalHARLoss(nn.Module):
    def __init__(self, use_reconstruction=True, use_invariance=True, use_disentanglement=True):
        super().__init__()
        self.use_reconstruction = use_reconstruction
        self.use_invariance = use_invariance
        self.use_disentanglement = use_disentanglement
        self.ce = nn.CrossEntropyLoss()
        self.mse = nn.MSELoss()
        self.l1 = nn.L1Loss()

    def stft_loss(self, x, x_recon):
        try:
            B, C, T = x.shape
            x_flat = x.view(-1, T)
            x_recon_flat = x_recon.view(-1, T)

            n_fft = min(32, T//2)
            hop_length = n_fft // 2
            win_length = n_fft

            if n_fft < 4:
                return torch.tensor(0.0, device=x.device)

            window = torch.hann_window(win_length, device=x.device)
            x_stft = torch.stft(x_flat, n_fft=n_fft, hop_length=hop_length,
                               win_length=win_length, window=window,
                               return_complex=True, center=False)
            x_recon_stft = torch.stft(x_recon_flat, n_fft=n_fft, hop_length=hop_length,
                                     win_length=win_length, window=window,
                                     return_complex=True, center=False)

            return F.mse_loss(x_stft.abs(), x_recon_stft.abs())
        except:
            return torch.tensor(0.0, device=x.device)

    def hsic_loss(self, z, n, batch_size):
        try:
            z = z.view(batch_size, -1)
            n = n.view(batch_size, -1)

            z_norm = F.normalize(z, dim=1, eps=1e-8)
            n_norm = F.normalize(n, dim=1, eps=1e-8)

            Kz = torch.mm(z_norm, z_norm.t())
            Kn = torch.mm(n_norm, n_norm.t())

            H = torch.eye(batch_size, device=z.device) - 1.0 / batch_size

            hsic_value = torch.trace(torch.mm(torch.mm(Kz, H), torch.mm(Kn, H))) / ((batch_size - 1) ** 2)
            return hsic_value
        except:
            return torch.tensor(0.0, device=z.device)

    def forward(self, logits, y, x, x_recon=None, z=None, n=None, z_prime=None):
        ce_loss = self.ce(logits, y)

        rec_loss = torch.tensor(0.0, device=logits.device)
        if self.use_reconstruction and x_recon is not None:
            rec_loss = 0.5 * self.mse(x_recon, x) + 0.5 * self.stft_loss(x, x_recon)

        inv_loss = torch.tensor(0.0, device=logits.device)
        if self.use_invariance and z is not None and z_prime is not None:
            inv_loss = self.mse(z, z_prime)

        dis_loss = torch.tensor(0.0, device=logits.device)
        if self.use_disentanglement and z is not None and n is not None:
            batch_size = z.shape[0]
            dis_loss = self.hsic_loss(z, n, batch_size)

        total_loss = ce_loss + 0.1 * rec_loss + 0.1 * inv_loss + 0.01 * dis_loss

        return total_loss, ce_loss.item(), rec_loss.item(), inv_loss.item(), dis_loss.item()

def show_confusion_matrix(cm, class_names, title="Confusion Matrix"):
    try:
        cm_norm = cm.astype('float') / (cm.sum(axis=1)[:, np.newaxis] + 1e-8)
        df = pd.DataFrame(cm_norm, index=class_names, columns=class_names)
        annot = pd.DataFrame(cm, index=class_names, columns=class_names)

        plt.figure(figsize=(6, 6))
        sns.heatmap(df, annot=annot.values, fmt="", cmap="Blues", cbar=True,
                    annot_kws={"size": 9}, vmin=0, vmax=1)
        plt.xticks(rotation=90, fontsize=9)
        plt.yticks(rotation=0, fontsize=9)
        for spine in plt.gca().spines.values():
            spine.set_visible(True)
            spine.set_linewidth(0.5)
            spine.set_edgecolor('black')
        plt.xlabel('Predicted Label', fontsize=10)
        plt.ylabel('True Label', fontsize=10)
        plt.title(title, fontsize=12)
        plt.tight_layout()
        plt.show()
    except Exception as e:
        print(f"Error plotting confusion matrix: {e}")

def plot_tsne(features, labels, activity_names, dataset_name="Dataset", samples_per_class=400):
    try:
        print(f"Input features shape: {features.shape}, labels shape: {labels.shape}")

        sampled_features, sampled_labels = [], []
        for i in range(len(activity_names)):
            class_mask = (labels == i)
            class_indices = np.where(class_mask)[0]

            if len(class_indices) > 0:
                if len(class_indices) >= samples_per_class:
                    selected_indices = np.random.choice(class_indices, samples_per_class, replace=False)
                else:
                    selected_indices = class_indices

                sampled_features.append(features[selected_indices])
                sampled_labels.append(labels[selected_indices])

        if not sampled_features:
            print("No valid samples found")
            return

        features_sampled = np.vstack(sampled_features)
        labels_sampled = np.concatenate(sampled_labels)

        print(f"Sampled features shape: {features_sampled.shape}, labels shape: {labels_sampled.shape}")

        features_2d = TSNE(n_components=2, perplexity=20, learning_rate=3000, random_state=42).fit_transform(features_sampled)

        colors = [
            "#FF0000",  # Red
            "#FFA500",  # Orange
            "#FFFF00",  # Yellow
            "#008000",  # Green
            "#00FFFF",  # Cyan
            "#0000FF",  # Blue
            "#800080",  # Purple
            "#FFC0CB",  # Pink
            "#A52A2A",  # Brown
            "#000000",  # Black
            "#808080",  # Gray
            "#FFD700",  # Gold
        ]

        plt.figure(figsize=(6, 5))
        for i, activity in enumerate(activity_names):
            mask = (labels_sampled == i)
            if np.any(mask):
                plt.scatter(
                    features_2d[mask, 0], features_2d[mask, 1],
                    color=colors[i], marker='o', s=20, alpha=0.4
                )

        handles = [
            plt.Line2D([0], [0], marker='o', color='w', label=activity,
                       markerfacecolor=colors[i], markersize=7)
            for i, activity in enumerate(activity_names)
        ]
        plt.legend(handles=handles, title="Activities", fontsize=9, framealpha=1)
        plt.xlabel("t-SNE Component 1", fontsize=13)
        plt.ylabel("t-SNE Component 2", fontsize=13)
        plt.title(f"t-SNE - {dataset_name}", fontsize=13)
        plt.grid(False)
        plt.tight_layout()
        plt.show()

    except Exception as e:
        print(f"Error creating t-SNE plot: {e}")

def compute_model_stats(model, input_shape=(9, 128)):
    try:
        device = next(model.parameters()).device
        dummy_input = torch.randn(1, *input_shape).to(device)
        model.eval()

        with torch.no_grad():
            classifier_original = model.classifier
            model.classifier = nn.Identity()
            macs_backbone, params_backbone = profile(model, inputs=(dummy_input,), verbose=False)
            model.classifier = classifier_original

            features = model.extract_features(dummy_input)
            macs_cls, params_cls = profile(model.classifier, inputs=(features,), verbose=False)

        total_macs_m = (macs_backbone + macs_cls) / 1e6
        total_params_m = (params_backbone + params_cls) / 1e6
        return total_params_m, total_macs_m
    except Exception as e:
        print(f"Error computing model stats: {e}")
        return 0.0, 0.0

def measure_inference_time(model, input_size=(1, 9, 128), device='cuda', n_runs=100, warmup=10):
    try:
        model.eval()
        inputs = torch.randn(input_size).to(device)
        psi = torch.zeros(input_size[0], 6, device=device)

        with torch.inference_mode():
            for _ in range(warmup):
                _ = model(inputs, psi)

        if device == 'cuda' and torch.cuda.is_available():
            torch.cuda.synchronize()

        start = time.time()
        with torch.inference_mode():
            for _ in range(n_runs):
                _ = model(inputs, psi)

        if device == 'cuda' and torch.cuda.is_available():
            torch.cuda.synchronize()

        end = time.time()
        return (end - start) / n_runs * 1000
    except Exception as e:
        print(f"Error measuring inference time: {e}")
        return 0.0

class Trainer:
    def __init__(self, model, loss_fn, optimizer, scheduler, device, activity_names, save_dir):
        self.model = model.to(device)
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.scheduler = scheduler
        self.device = device
        self.activity_names = activity_names
        self.save_dir = save_dir
        os.makedirs(save_dir, exist_ok=True)
        self.best_f1 = 0
        self.best_metrics = {}

    def train_epoch(self, train_loader, val_loader, epoch):
        self.model.train()
        train_loss = 0
        train_correct = 0
        train_total = 0
        ce_losses = []
        rec_losses = []
        inv_losses = []
        dis_losses = []

        for batch_idx, (x, y) in enumerate(train_loader):
            try:
                x, y = x.to(self.device), y.to(self.device)
                psi = extract_physics_features(x)
                x_aug = DoAugmentation.apply_random_augmentation(x)
                psi_aug = extract_physics_features(x_aug)

                logits, z, n, x_recon = self.model(x, psi)
                _, z_prime, _, _ = self.model(x_aug, psi_aug)

                loss, ce, rec, inv, dis = self.loss_fn(logits, y, x, x_recon, z, n, z_prime)

                self.optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), 1.0)
                self.optimizer.step()

                train_loss += loss.item()
                pred = logits.argmax(dim=1)
                train_correct += (pred == y).sum().item()
                train_total += y.size(0)
                ce_losses.append(ce)
                rec_losses.append(rec)
                inv_losses.append(inv)
                dis_losses.append(dis)

            except Exception as e:
                print(f"Error in training step {batch_idx}: {e}")
                continue

        train_acc = train_correct / max(train_total, 1)
        avg_train_loss = train_loss / max(len(train_loader), 1)
        avg_ce = np.mean(ce_losses) if ce_losses else 0
        avg_rec = np.mean(rec_losses) if rec_losses else 0
        avg_inv = np.mean(inv_losses) if inv_losses else 0
        avg_dis = np.mean(dis_losses) if dis_losses else 0

        self.model.eval()
        val_loss = 0
        val_correct = 0
        val_total = 0
        all_preds, all_labels, all_z = [], [], []

        with torch.no_grad():
            for batch_idx, (x, y) in enumerate(val_loader):
                try:
                    x, y = x.to(self.device), y.to(self.device)
                    psi = extract_physics_features(x)
                    logits, z, n, x_recon = self.model(x, psi)
                    loss, _, _, _, _ = self.loss_fn(logits, y, x, x_recon, z, n)

                    val_loss += loss.item()
                    pred = logits.argmax(dim=1)
                    val_correct += (pred == y).sum().item()
                    val_total += y.size(0)
                    all_preds.extend(pred.cpu().numpy())
                    all_labels.extend(y.cpu().numpy())

                    z_flat = z.view(z.size(0), -1).cpu().numpy()
                    all_z.extend(z_flat)

                except Exception as e:
                    print(f"Error in validation step {batch_idx}: {e}")
                    continue

        val_acc = val_correct / max(val_total, 1)
        avg_val_loss = val_loss / max(len(val_loader), 1)

        if epoch % 25 == 0:
            print(f"Epoch {epoch} | "
                  f"Train Loss: {avg_train_loss:.6f} | Train Acc: {train_acc:.4f} | "
                  f"Val Loss: {avg_val_loss:.6f} | Val Acc: {val_acc:.4f}")
            print(f"          CE: {avg_ce:.6f} | Rec: {avg_rec:.6f} | Inv: {avg_inv:.6f} | Dis: {avg_dis:.6f}")

        if all_preds and all_labels:
            f1_macro = f1_score(all_labels, all_preds, average='macro', zero_division=0)
            if f1_macro > self.best_f1:
                self.best_f1 = f1_macro
                self.best_metrics = {
                    'acc': val_acc,
                    'f1_macro': f1_macro,
                    'f1_weighted': f1_score(all_labels, all_preds, average='weighted', zero_division=0),
                    'precision': precision_score(all_labels, all_preds, average='macro', zero_division=0),
                    'recall': recall_score(all_labels, all_preds, average='macro', zero_division=0),
                    'params': compute_model_stats(self.model)[0],
                    'flops': compute_model_stats(self.model)[1],
                    'inf_ms': measure_inference_time(self.model, device=self.device),
                    'cm': confusion_matrix(all_labels, all_preds),
                    'z': np.array(all_z),
                    'preds': np.array(all_preds),
                    'labels': np.array(all_labels)
                }

        if self.scheduler:
            self.scheduler.step()

    def get_best_results(self):
        return self.best_metrics

    def show_final_results(self, config_name):
        if not self.best_metrics:
            print("No best metrics available")
            return

        print(f"\n{'='*50}")
        print(f"FINAL RESULTS FOR {config_name}")
        print(f"{'='*50}")
        print(f"Accuracy: {self.best_metrics['acc']:.4f}")
        print(f"F1 (macro): {self.best_metrics['f1_macro']:.4f}")
        print(f"F1 (weighted): {self.best_metrics['f1_weighted']:.4f}")
        print(f"Precision: {self.best_metrics['precision']:.4f}")
        print(f"Recall: {self.best_metrics['recall']:.4f}")
        print(f"Parameters (M): {self.best_metrics['params']:.2f}")
        print(f"FLOPs (M): {self.best_metrics['flops']:.2f}")
        print(f"Inference (ms): {self.best_metrics['inf_ms']:.2f}")

        print(f"\nConfusion Matrix for {config_name}:")
        show_confusion_matrix(self.best_metrics['cm'], self.activity_names,
                             f"Confusion Matrix - {config_name}")

        print(f"\nt-SNE Visualization for {config_name}:")
        plot_tsne(self.best_metrics['z'], self.best_metrics['labels'],
                 self.activity_names, config_name, samples_per_class=400)

def run_ablation_study(data_root=None):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    if data_root is None:
        data_root = "/content/drive/MyDrive/HAR_Dataset/UCI"
        if not os.path.exists(data_root):
            print(f"Data directory {data_root} not found. Please provide correct path.")
            return

    try:
        X_all, y_all, _, activity_names = load_full_uci_har_data(data_root)
        dataset = HARDataset(X_all, y_all)
        indices = np.arange(len(dataset))
        np.random.shuffle(indices)
        train_size = int(0.7 * len(dataset))
        train_idx, val_idx = indices[:train_size], indices[train_size:]
        train_set = torch.utils.data.Subset(dataset, train_idx)
        val_set = torch.utils.data.Subset(dataset, val_idx)
        train_loader = DataLoader(train_set, batch_size=512, shuffle=True, num_workers=2, pin_memory=True, drop_last=True)
        val_loader = DataLoader(val_set, batch_size=512, shuffle=False, num_workers=2, pin_memory=True)

        configs = [
            ("Full", True, True, True, True),
            ("w_o_FiLM", False, True, True, True),
            ("w_o_Inv", True, True, False, True),
            ("w_o_Dis", True, True, True, False),
            ("w_o_Dec", True, False, True, True),
            ("Baseline", False, False, False, False),
        ]

        results = []
        for name, use_film, use_decoder, use_inv, use_dis in configs:
            print(f"\n{'='*60}")
            print(f"RUNNING: {name}")
            print(f"{'='*60}")
            save_dir = f"./results/{name}"
            os.makedirs(save_dir, exist_ok=True)

            try:
                model = CausalManifoldHAR(use_film=use_film, use_decoder=use_decoder)
                loss_fn = CausalHARLoss(use_reconstruction=use_decoder, use_invariance=use_inv, use_disentanglement=use_dis)
                optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-5)
                scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)
                trainer = Trainer(model, loss_fn, optimizer, scheduler, device, activity_names, save_dir)

                for epoch in range(1, 201):
                    trainer.train_epoch(train_loader, val_loader, epoch)

                best = trainer.get_best_results()
                if best:
                    results.append({
                        'Config': name,
                        'F1(m)': best.get('f1_macro', 0),
                        'Acc': best.get('acc', 0),
                        'Prec': best.get('precision', 0),
                        'Rec': best.get('recall', 0),
                        'Params(M)': best.get('params', 0),
                        'FLOPs(M)': best.get('flops', 0),
                        'Inf(ms)': best.get('inf_ms', 0),
                    })

                    trainer.show_final_results(name)

            except Exception as e:
                print(f"Error in config {name}: {e}")
                continue

        if results:
            print(f"\n{'='*80}")
            print("FINAL ABLATION STUDY RESULTS")
            print(f"{'='*80}")
            rst_df = pd.DataFrame(results).round(4)
            display(rst_df)
            print("Ablation study completed successfully!")
        else:
            print("No results were generated. Check for errors above.")

    except Exception as e:
        print(f"Error in ablation study: {e}")

if __name__ == "__main__":
    run_ablation_study()
# Out:
# Using device: cuda
# Loaded all data: X=(10299, 9, 128), y=(10299,), Subjects=30
#
# ============================================================
# RUNNING: Full
# ============================================================
# Epoch 25 | Train Loss: 0.167807 | Train Acc: 0.9501 | Val Loss: 0.198106 | Val Acc: 0.9421
#           CE: 0.116615 | Rec: 0.455566 | Inv: 0.054823 | Dis: 0.015300
# Epoch 50 | Train Loss: 0.152464 | Train Acc: 0.9549 | Val Loss: 0.180248 | Val Acc: 0.9537
#           CE: 0.105444 | Rec: 0.411836 | Inv: 0.057654 | Dis: 0.007127
# Epoch 75 | Train Loss: 0.145027 | Train Acc: 0.9581 | Val Loss: 0.178098 | Val Acc: 0.9508
#           CE: 0.101347 | Rec: 0.404401 | Inv: 0.031872 | Dis: 0.005236
# Epoch 100 | Train Loss: 0.141743 | Train Acc: 0.9583 | Val Loss: 0.168816 | Val Acc: 0.9592
#           CE: 0.098724 | Rec: 0.389756 | Inv: 0.040000 | Dis: 0.004351
# Epoch 125 | Train Loss: 0.137316 | Train Acc: 0.9611 | Val Loss: 0.168695 | Val Acc: 0.9560
#           CE: 0.094301 | Rec: 0.390183 | Inv: 0.039576 | Dis: 0.003904
# Epoch 150 | Train Loss: 0.134179 | Train Acc: 0.9614 | Val Loss: 0.170023 | Val Acc: 0.9557
#           CE: 0.093650 | Rec: 0.382184 | Inv: 0.022749 | Dis: 0.003643
# Epoch 175 | Train Loss: 0.132854 | Train Acc: 0.9630 | Val Loss: 0.162783 | Val Acc: 0.9579
#           CE: 0.092291 | Rec: 0.374684 | Inv: 0.030595 | Dis: 0.003459
# Epoch 200 | Train Loss: 0.131390 | Train Acc: 0.9615 | Val Loss: 0.166543 | Val Acc: 0.9573
#           CE: 0.092000 | Rec: 0.377654 | Inv: 0.015904 | Dis: 0.003428
#
# ==================================================
# FINAL RESULTS FOR Full
# ==================================================
# Accuracy: 0.9599
# F1 (macro): 0.9607
# F1 (weighted): 0.9599
# Precision: 0.9607
# Recall: 0.9615
# Parameters (M): 0.11
# FLOPs (M): 14.51
# Inference (ms): 1.25
#
# Confusion Matrix for Full:
# t-SNE Visualization for Full:
# Input features shape: (3090, 16384), labels shape: (3090,)
# Sampled features shape: (2400, 16384), labels shape: (2400,)
# ============================================================
# RUNNING: w_o_FiLM
# ============================================================
# Epoch 25 | Train Loss: 0.201988 | Train Acc: 0.9478 | Val Loss: 0.225894 | Val Acc: 0.9495
#           CE: 0.125790 | Rec: 0.706089 | Inv: 0.054574 | Dis: 0.013128
# Epoch 50 | Train Loss: 0.185645 | Train Acc: 0.9523 | Val Loss: 0.223827 | Val Acc: 0.9424
#           CE: 0.112312 | Rec: 0.682553 | Inv: 0.050065 | Dis: 0.007097
# Epoch 75 | Train Loss: 0.177127 | Train Acc: 0.9513 | Val Loss: 0.209009 | Val Acc: 0.9505
#           CE: 0.107281 | Rec: 0.670721 | Inv: 0.027184 | Dis: 0.005546
# Epoch 100 | Train Loss: 0.170117 | Train Acc: 0.9558 | Val Loss: 0.201207 | Val Acc: 0.9537
#           CE: 0.103136 | Rec: 0.661824 | Inv: 0.007520 | Dis: 0.004610
# Epoch 125 | Train Loss: 0.168056 | Train Acc: 0.9562 | Val Loss: 0.205661 | Val Acc: 0.9495
#           CE: 0.100286 | Rec: 0.652807 | Inv: 0.024475 | Dis: 0.004220
# Epoch 150 | Train Loss: 0.166668 | Train Acc: 0.9570 | Val Loss: 0.202775 | Val Acc: 0.9508
#           CE: 0.099785 | Rec: 0.650063 | Inv: 0.018365 | Dis: 0.004038
# Epoch 175 | Train Loss: 0.166211 | Train Acc: 0.9568 | Val Loss: 0.206454 | Val Acc: 0.9508
#           CE: 0.099019 | Rec: 0.644279 | Inv: 0.027249 | Dis: 0.003901
# Epoch 200 | Train Loss: 0.164188 | Train Acc: 0.9587 | Val Loss: 0.202214 | Val Acc: 0.9502
#           CE: 0.097516 | Rec: 0.645280 | Inv: 0.021043 | Dis: 0.003938
#
# ==================================================
# FINAL RESULTS FOR w_o_FiLM
# ==================================================
# Accuracy: 0.9553
# F1 (macro): 0.9563
# F1 (weighted): 0.9554
# Precision: 0.9561
# Recall: 0.9564
# Parameters (M): 0.11
# FLOPs (M): 14.51
# Inference (ms): 0.69
#
# Confusion Matrix for w_o_FiLM:
# t-SNE Visualization for w_o_FiLM:
# Input features shape: (3090, 16384), labels shape: (3090,)
# Sampled features shape: (2400, 16384), labels shape: (2400,)
# ============================================================
# RUNNING: w_o_Inv
# ============================================================
# Epoch 25 | Train Loss: 0.190447 | Train Acc: 0.9519 | Val Loss: 0.228532 | Val Acc: 0.9479
#           CE: 0.113326 | Rec: 0.769508 | Inv: 0.000000 | Dis: 0.016948
# Epoch 50 | Train Loss: 0.159779 | Train Acc: 0.9562 | Val Loss: 0.200886 | Val Acc: 0.9443
#           CE: 0.102408 | Rec: 0.573108 | Inv: 0.000000 | Dis: 0.005981
# Epoch 75 | Train Loss: 0.153005 | Train Acc: 0.9555 | Val Loss: 0.183788 | Val Acc: 0.9547
#           CE: 0.102134 | Rec: 0.508248 | Inv: 0.000000 | Dis: 0.004580
# Epoch 100 | Train Loss: 0.148318 | Train Acc: 0.9580 | Val Loss: 0.178961 | Val Acc: 0.9540
#           CE: 0.098706 | Rec: 0.495698 | Inv: 0.000000 | Dis: 0.004220
# Epoch 125 | Train Loss: 0.144159 | Train Acc: 0.9593 | Val Loss: 0.183207 | Val Acc: 0.9550
#           CE: 0.094850 | Rec: 0.492690 | Inv: 0.000000 | Dis: 0.004045
# Epoch 150 | Train Loss: 0.143301 | Train Acc: 0.9594 | Val Loss: 0.174519 | Val Acc: 0.9589
#           CE: 0.095076 | Rec: 0.481866 | Inv: 0.000000 | Dis: 0.003790
# Epoch 175 | Train Loss: 0.140549 | Train Acc: 0.9618 | Val Loss: 0.174087 | Val Acc: 0.9560
#           CE: 0.092319 | Rec: 0.481929 | Inv: 0.000000 | Dis: 0.003763
# Epoch 200 | Train Loss: 0.141334 | Train Acc: 0.9605 | Val Loss: 0.174261 | Val Acc: 0.9557
#           CE: 0.093346 | Rec: 0.479513 | Inv: 0.000000 | Dis: 0.003732
#
# ==================================================
# FINAL RESULTS FOR w_o_Inv
# ==================================================
# Accuracy: 0.9589
# F1 (macro): 0.9597
# F1 (weighted): 0.9589
# Precision: 0.9596
# Recall: 0.9603
# Parameters (M): 0.11
# FLOPs (M): 14.51
# Inference (ms): 0.72
#
# Confusion Matrix for w_o_Inv:
# t-SNE Visualization for w_o_Inv:
# Input features shape: (3090, 16384), labels shape: (3090,)
# Sampled features shape: (2400, 16384), labels shape: (2400,)
# ============================================================
# RUNNING: w_o_Dis
# ============================================================
# Epoch 25 | Train Loss: 0.183293 | Train Acc: 0.9509 | Val Loss: 0.212695 | Val Acc: 0.9472
#           CE: 0.116796 | Rec: 0.612517 | Inv: 0.052448 | Dis: 0.000000
# Epoch 50 | Train Loss: 0.168034 | Train Acc: 0.9540 | Val Loss: 0.196849 | Val Acc: 0.9518
#           CE: 0.105277 | Rec: 0.572105 | Inv: 0.055467 | Dis: 0.000000
# Epoch 75 | Train Loss: 0.162188 | Train Acc: 0.9556 | Val Loss: 0.192492 | Val Acc: 0.9531
#           CE: 0.102172 | Rec: 0.557857 | Inv: 0.042311 | Dis: 0.000000
# Epoch 100 | Train Loss: 0.156611 | Train Acc: 0.9579 | Val Loss: 0.186099 | Val Acc: 0.9576
#           CE: 0.099329 | Rec: 0.539171 | Inv: 0.033645 | Dis: 0.000000
# Epoch 125 | Train Loss: 0.152373 | Train Acc: 0.9588 | Val Loss: 0.184471 | Val Acc: 0.9547
#           CE: 0.097021 | Rec: 0.534312 | Inv: 0.019204 | Dis: 0.000000
# Epoch 150 | Train Loss: 0.151057 | Train Acc: 0.9597 | Val Loss: 0.182308 | Val Acc: 0.9579
#           CE: 0.095475 | Rec: 0.527391 | Inv: 0.028431 | Dis: 0.000000
# Epoch 175 | Train Loss: 0.149250 | Train Acc: 0.9604 | Val Loss: 0.181866 | Val Acc: 0.9560
#           CE: 0.094407 | Rec: 0.524320 | Inv: 0.024112 | Dis: 0.000000
# Epoch 200 | Train Loss: 0.149096 | Train Acc: 0.9604 | Val Loss: 0.181608 | Val Acc: 0.9557
#           CE: 0.094016 | Rec: 0.525754 | Inv: 0.025045 | Dis: 0.000000
#
# ==================================================
# FINAL RESULTS FOR w_o_Dis
# ==================================================
# Accuracy: 0.9595
# F1 (macro): 0.9603
# F1 (weighted): 0.9596
# Precision: 0.9603
# Recall: 0.9607
# Parameters (M): 0.11
# FLOPs (M): 14.51
# Inference (ms): 1.02
#
# Confusion Matrix for w_o_Dis:
# t-SNE Visualization for w_o_Dis:
# Input features shape: (3090, 16384), labels shape: (3090,)
# Sampled features shape: (2400, 16384), labels shape: (2400,)
# ============================================================
# RUNNING: w_o_Dec
# ============================================================
# Epoch 25 | Train Loss: 0.129045 | Train Acc: 0.9501 | Val Loss: 0.150431 | Val Acc: 0.9521
#           CE: 0.116155 | Rec: 0.000000 | Inv: 0.128861 | Dis: 0.000385
# Epoch 50 | Train Loss: 0.108400 | Train Acc: 0.9572 | Val Loss: 0.134979 | Val Acc: 0.9537
#           CE: 0.102627 | Rec: 0.000000 | Inv: 0.057708 | Dis: 0.000239
# Epoch 75 | Train Loss: 0.099989 | Train Acc: 0.9594 | Val Loss: 0.131115 | Val Acc: 0.9563
#           CE: 0.098199 | Rec: 0.000000 | Inv: 0.017877 | Dis: 0.000190
# Epoch 100 | Train Loss: 0.098336 | Train Acc: 0.9615 | Val Loss: 0.128690 | Val Acc: 0.9573
#           CE: 0.095154 | Rec: 0.000000 | Inv: 0.031797 | Dis: 0.000173
# Epoch 125 | Train Loss: 0.098366 | Train Acc: 0.9597 | Val Loss: 0.127767 | Val Acc: 0.9560
#           CE: 0.094743 | Rec: 0.000000 | Inv: 0.036215 | Dis: 0.000143
# Epoch 150 | Train Loss: 0.094819 | Train Acc: 0.9612 | Val Loss: 0.127277 | Val Acc: 0.9595
#           CE: 0.092112 | Rec: 0.000000 | Inv: 0.027058 | Dis: 0.000132
# Epoch 175 | Train Loss: 0.095792 | Train Acc: 0.9628 | Val Loss: 0.128354 | Val Acc: 0.9583
#           CE: 0.091981 | Rec: 0.000000 | Inv: 0.038100 | Dis: 0.000125
# Epoch 200 | Train Loss: 0.094482 | Train Acc: 0.9622 | Val Loss: 0.129032 | Val Acc: 0.9586
#           CE: 0.091172 | Rec: 0.000000 | Inv: 0.033091 | Dis: 0.000126
#
# ==================================================
# FINAL RESULTS FOR w_o_Dec
# ==================================================
# Accuracy: 0.9608
# F1 (macro): 0.9616
# F1 (weighted): 0.9609
# Precision: 0.9615
# Recall: 0.9622
# Parameters (M): 0.04
# FLOPs (M): 4.75
# Inference (ms): 0.51
#
# Confusion Matrix for w_o_Dec:
# t-SNE Visualization for w_o_Dec:
# Input features shape: (3090, 16384), labels shape: (3090,)
# Sampled features shape: (2400, 16384), labels shape: (2400,)
# ============================================================
# RUNNING: Baseline
# ============================================================
# Epoch 25 | Train Loss: 0.123945 | Train Acc: 0.9487 | Val Loss: 0.161143 | Val Acc: 0.9479
#           CE: 0.123945 | Rec: 0.000000 | Inv: 0.000000 | Dis: 0.000000
# Epoch 50 | Train Loss: 0.111917 | Train Acc: 0.9499 | Val Loss: 0.145201 | Val Acc: 0.9505
#           CE: 0.111917 | Rec: 0.000000 | Inv: 0.000000 | Dis: 0.000000
# Epoch 75 | Train Loss: 0.107500 | Train Acc: 0.9538 | Val Loss: 0.145312 | Val Acc: 0.9463
#           CE: 0.107500 | Rec: 0.000000 | Inv: 0.000000 | Dis: 0.000000
# Epoch 100 | Train Loss: 0.104064 | Train Acc: 0.9516 | Val Loss: 0.135939 | Val Acc: 0.9505
#           CE: 0.104064 | Rec: 0.000000 | Inv: 0.000000 | Dis: 0.000000
# Epoch 125 | Train Loss: 0.101150 | Train Acc: 0.9565 | Val Loss: 0.138307 | Val Acc: 0.9508
#           CE: 0.101150 | Rec: 0.000000 | Inv: 0.000000 | Dis: 0.000000
# Epoch 150 | Train Loss: 0.099244 | Train Acc: 0.9574 | Val Loss: 0.135498 | Val Acc: 0.9511
#           CE: 0.099244 | Rec: 0.000000 | Inv: 0.000000 | Dis: 0.000000
# Epoch 175 | Train Loss: 0.098113 | Train Acc: 0.9569 | Val Loss: 0.135868 | Val Acc: 0.9511
#           CE: 0.098113 | Rec: 0.000000 | Inv: 0.000000 | Dis: 0.000000
# Epoch 200 | Train Loss: 0.099420 | Train Acc: 0.9565 | Val Loss: 0.134978 | Val Acc: 0.9502
#           CE: 0.099420 | Rec: 0.000000 | Inv: 0.000000 | Dis: 0.000000
#
# ==================================================
# FINAL RESULTS FOR Baseline
# ==================================================
# Accuracy: 0.9566
# F1 (macro): 0.9575
# F1 (weighted): 0.9567
# Precision: 0.9574
# Recall: 0.9576
# Parameters (M): 0.04
# FLOPs (M): 4.75
# Inference (ms): 0.36
#
# Confusion Matrix for Baseline:
# t-SNE Visualization for Baseline:
# Input features shape: (3090, 16384), labels shape: (3090,)
# Sampled features shape: (2400, 16384), labels shape: (2400,)
# ================================================================================
# FINAL ABLATION STUDY RESULTS
# ================================================================================
#      Config   F1(m)     Acc    Prec     Rec  Params(M)  FLOPs(M)  Inf(ms)
# 0      Full  0.9607  0.9599  0.9607  0.9615     0.1137   14.5089   1.2520
# 1  w_o_FiLM  0.9563  0.9553  0.9561  0.9564     0.1137   14.5089   0.6856
# 2   w_o_Inv  0.9597  0.9589  0.9596  0.9603     0.1137   14.5089   0.7233
# 3   w_o_Dis  0.9603  0.9595  0.9603  0.9607     0.1137   14.5089   1.0222
# 4   w_o_Dec  0.9616  0.9608  0.9615  0.9622     0.0376    4.7523   0.5063
# 5  Baseline  0.9575  0.9566  0.9574  0.9576     0.0376    4.7523   0.3612
# Ablation study completed successfully!
